# %% [markdown]
# # API Scavenger Game
#
# ## Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp.

# %%
import pandas as pd
import requests
import numpy as np
import base64

# %%
headers = {'Authorization': 'token d911e039c5daf4457a1dfd9153d467335809d4b7'}

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# #### 1. Obtain the full list of forks created from the main lab repo via Github API.

# %% [markdown]
# To list forks, we can use the GET method. As explained in the GitHub API documentation, we need to make the request to: GET /repos/:owner/:repo/forks.

# %%
response = requests.get('http://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks', headers=headers)
pd.json_normalize(response.json())['full_name']
response
# Out:
# <Response [200]>

# %% [markdown]
# #### 2. Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like: ["Python", "Jupyter Notebook", "HTML"]

# %%
lang = pd.json_normalize(response.json())['language'].unique()
lang
# Out:
# array([None, 'Jupyter Notebook', 'HTML'], dtype=object)

# %% [markdown]
# ## Challenge 2: Count Commits
# Count how many commits were made in the month of october of 2018.
# #### 1. Obtain all the commits made in October 2018 via API, which is a JSON array that contains multiple commit objects.

# %%
response = requests.get('http://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits', headers=headers)
com = pd.json_normalize(response.json())
conditions = (com['commit.author.date'] >= '2018-01-10') & (com['commit.author.date'] <= '2018-31-10')
com[conditions]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# #### 2. Count how many commit objects are contained in the array.

# %%
commits = com[conditions]
commits.shape[0]
# Out:
# 0

# %% [markdown]
# ## Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
# #### 1. Find the secret files.

# %%
response = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/contents', headers=headers)
response.json()

secret_files = []

for folder in response.json():
    if folder['type'] == 'dir':
        response = requests.get(folder['url'], headers=headers)
        a = response.json()
        for file in a:
            if file['name'].endswith('.scavengerhunt'):
                secret_files.append(file)

# %%
pd.json_normalize(secret_files)
# Out:
#                    name                       path  \
# 0   .0006.scavengerhunt  15024/.0006.scavengerhunt
# 1   .0008.scavengerhunt  15534/.0008.scavengerhunt
# 2   .0012.scavengerhunt  15534/.0012.scavengerhunt
# 3   .0007.scavengerhunt  17020/.0007.scavengerhunt
# 4   .0021.scavengerhunt  30351/.0021.scavengerhunt
# 5   .0022.scavengerhunt  40303/.0022.scavengerhunt
# 6   .0005.scavengerhunt  44639/.0005.scavengerhunt
# 7   .0018.scavengerhunt  45525/.0018.scavengerhunt
# 8   .0016.scavengerhunt  47222/.0016.scavengerhunt
# 9   .0024.scavengerhunt  47222/.0024.scavengerhunt
# 10  .0010.scavengerhunt  47830/.0010.scavengerhunt
# 11  .0014.scavengerhunt  49418/.0014.scavengerhunt
# 12  .0011.scavengerhunt  50896/.0011.scavengerhunt
# 13  .0023.scavengerhunt  55417/.0023.scavengerhunt
# 14  .0020.scavengerhunt  55685/.0020.scavengerhunt
# 15  .0003.scavengerhunt  60224/.0003.scavengerhunt
# 16  .0004.scavengerhunt  68848/.0004.scavengerhunt
# ...

# %% [markdown]
# #### 2.  Sort the filenames ascendingly.

# %%
df = pd.json_normalize(secret_files)

secret_files = df.sort_values(['name'])
secret_files
# Out:
#                    name                       path  \
# 23  .0001.scavengerhunt  98750/.0001.scavengerhunt
# 19  .0002.scavengerhunt  88596/.0002.scavengerhunt
# 15  .0003.scavengerhunt  60224/.0003.scavengerhunt
# 16  .0004.scavengerhunt  68848/.0004.scavengerhunt
# 6   .0005.scavengerhunt  44639/.0005.scavengerhunt
# 0   .0006.scavengerhunt  15024/.0006.scavengerhunt
# 3   .0007.scavengerhunt  17020/.0007.scavengerhunt
# 1   .0008.scavengerhunt  15534/.0008.scavengerhunt
# 22  .0009.scavengerhunt  97881/.0009.scavengerhunt
# 10  .0010.scavengerhunt  47830/.0010.scavengerhunt
# 12  .0011.scavengerhunt  50896/.0011.scavengerhunt
# 2   .0012.scavengerhunt  15534/.0012.scavengerhunt
# 20  .0013.scavengerhunt  89338/.0013.scavengerhunt
# 11  .0014.scavengerhunt  49418/.0014.scavengerhunt
# 21  .0015.scavengerhunt  91701/.0015.scavengerhunt
# 8   .0016.scavengerhunt  47222/.0016.scavengerhunt
# 18  .0017.scavengerhunt  70985/.0017.scavengerhunt
# ...

# %% [markdown]
# #### 3. Read the content of each secret files into an array of strings.
# Since the response is encoded, you will need to send the following information in the header of your request:
# ````python
# headers = {'Accept': 'application/vnd.github.v3.raw'}
# ````

# %%
joke = []

for url in secret_files['url']:
    response = requests.get(url, headers={'Authorization': 'token d911e039c5daf4457a1dfd9153d467335809d4b7', 'Accept': 'application/vnd.github.v3.raw'})
    joke.append(response.text.strip())

# %% [markdown]
# #### 4. Concatenate the strings in the array separating each two with a whitespace.

# %%
joke = ' '.join(joke)

# %% [markdown]
# #### 5. Print out the joke.

# %%
joke
# Out:
# 'In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.'
